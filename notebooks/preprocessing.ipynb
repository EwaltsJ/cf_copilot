# %% [markdown]
# # A)Data Retrieval and Preprocessing

# %% [markdown]
# ## Data Retrieval

# %%
# !pip install kagglehub
# Out:
# Collecting kagglehub
#   Downloading kagglehub-1.0.0-py3-none-any.whl.metadata (40 kB)
# Collecting kagglesdk<1.0,>=0.1.14 (from kagglehub)
#   Downloading kagglesdk-0.1.16-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in /home/saiyudh/.pyenv/versions/3.10.6/envs/cf_copilot/lib/python3.10/site-packages (from kagglehub) (26.0)
# Requirement already satisfied: pyyaml in /home/saiyudh/.pyenv/versions/3.10.6/envs/cf_copilot/lib/python3.10/site-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in /home/saiyudh/.pyenv/versions/3.10.6/envs/cf_copilot/lib/python3.10/site-packages (from kagglehub) (2.32.5)
# Requirement already satisfied: tqdm in /home/saiyudh/.pyenv/versions/3.10.6/envs/cf_copilot/lib/python3.10/site-packages (from kagglehub) (4.67.3)
# Requirement already satisfied: protobuf in /home/saiyudh/.pyenv/versions/3.10.6/envs/cf_copilot/lib/python3.10/site-packages (from kagglesdk<1.0,>=0.1.14->kagglehub) (7.34.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/saiyudh/.pyenv/versions/3.10.6/envs/cf_copilot/lib/python3.10/site-packages (from requests->kagglehub) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /home/saiyudh/.pyenv/versions/3.10.6/envs/cf_copilot/lib/python3.10/site-packages (from requests->kagglehub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/saiyudh/.pyenv/versions/3.10.6/envs/cf_copilot/lib/python3.10/site-packages (from requests->kagglehub) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/saiyudh/.pyenv/versions/3.10.6/envs/cf_copilot/lib/python3.10/site-packages (from requests->kagglehub) (2026.2.25)
# Downloading kagglehub-1.0.0-py3-none-any.whl (70 kB)
# Downloading kagglesdk-0.1.16-py3-none-any.whl (160 kB)
# Installing collected packages: kagglesdk, kagglehub
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [kagglehub]/2 [kagglehub]
# Successfully installed kagglehub-1.0.0 kagglesdk-0.1.16

# %%
from pathlib import Path
import pandas as pd
import kagglehub
from kagglehub import KaggleDatasetAdapter

def load_cashflow_data(csv_name: str = "dataset.csv") -> pd.DataFrame:
    # 1) Look for local file first: ../raw_data/dataset.csv
    base_dir = Path.cwd().parent          # one level up from notebook
    raw_data_dir = base_dir / "raw_data"
    raw_data_dir.mkdir(parents=True, exist_ok=True)
    local_path = raw_data_dir / csv_name

    if local_path.is_file():
        print(f"Loading local file: {local_path}")
        return pd.read_csv(local_path)

    # 2) If not found, download from Kaggle once via kagglehub
    print("Local file not found, downloading from Kaggle via kagglehub...")
    df = kagglehub.dataset_load(
        KaggleDatasetAdapter.PANDAS,
        "pradumn203/payment-date-prediction-for-invoices-dataset",
        "dataset.csv",  # main CSV name on Kaggle
    )  # [web:83][web:88][web:25]

    # Save for future offline use
    df.to_csv(local_path, index=False)
    print(f"Saved local copy to {local_path}")

    return df

df = load_cashflow_data()
# Out:
# Local file not found, downloading from Kaggle via kagglehub...
# Saved local copy to /home/saiyudh/code/EwaltsJ/cf_copilot/raw_data/dataset.csv

# %% [markdown]
# ## Feature Extraction and Engineering

# %% [markdown]
# ## Data Preprocessing and Wrangling

# %% [markdown]
# ## Feature Scaling & Selection

# %% [markdown]
# # B)ALGO Testing

# %% [markdown]
# # C)Model Eval and Tuning

# %% [markdown]
# # D)Pipeline
